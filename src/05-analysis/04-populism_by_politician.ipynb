# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sqlalchemy import case
from sqlalchemy import literal
from sqlalchemy.orm import Query

import src
import src.db.models.bert_data as bm
import src.db.models.open_discourse as od

# %%
pd.set_option("display.max_colwidth", 2048)
pd.set_option("display.max_rows", 256)

engine = src.db.connect.make_engine("DB")

# %% [markdown]
# # Load data

# %%
thresh = {"elite": 0.5013018, "centr": 0.5017193, "left": 0.42243505, "right": 0.38281676}

# %%
colormap = {
    "CDU/CSU": "#000000",
    "Grüne": "#1AA037",
    "DIE LINKE.": "#8B008B",
    "FDP": "#FFEF00",
    "AfD": "#0489DB",
    "SPD": "#E3000F",
}

# %%
query = (
    Query(bm.Sample)
    .join(bm.Prediction)
    .join(od.Speech)
    .join(od.Faction)
    .join(od.Politician)
    .filter(
        bm.Sample.sentence_length > 2,
        od.Faction.abbreviation != "Fraktionslos",
    )
    .with_entities(
        od.Speech.id.label("speech_id"),
        od.Speech.electoral_term,
        od.Speech.date,
        bm.Sample.sentence_no,
        od.Politician.id.label("pol_id"),
        od.Politician.first_name,
        od.Politician.last_name,
        od.Faction.abbreviation,
        case(
            (bm.Prediction.elite >= thresh["elite"], literal(1)),
            (bm.Prediction.elite < thresh["elite"], literal(0)),
        ).label("antielite"),
        case(
            (bm.Prediction.pplcentr >= thresh["centr"], literal(1)),
            (bm.Prediction.pplcentr < thresh["centr"], literal(0)),
        ).label("pplcentr"),
        case(
            (bm.Prediction.left >= thresh["left"], literal(1)),
            (bm.Prediction.left < thresh["left"], literal(0)),
        ).label("left"),
        case(
            (bm.Prediction.right >= thresh["right"], literal(1)),
            (bm.Prediction.right < thresh["right"], literal(0)),
        ).label("right"),
    )
)

# %%
with engine.connect() as conn:
    df_raw = pd.read_sql(query.statement, conn)
df_raw.date = pd.to_datetime(df_raw.date)

# %%
# filter all speeches with less than 3 sentences
df_raw = df_raw.groupby("speech_id").filter(lambda x: x["sentence_no"].max() > 3)

# %%
assert len(df_raw) == df_raw.groupby(["speech_id", "sentence_no"]).ngroups

# %% [markdown]
# # Basic sentence level stats

# %%
len(df_raw)
# Out:
# 1258876

# %%
(df_raw.iloc[:, 8:].sum() / len(df_raw) * 100).round(1)
# Out:
# antielite    6.7
# pplcentr     2.2
# left         1.1
# right        0.6
# dtype: float64

# %%
pop_total = df_raw["antielite"] * df_raw["pplcentr"]
pop_total = pop_total.apply(lambda x: 0 if x == 0 else 1)
print(pop_total.value_counts(normalize=False))
pop_total.value_counts(normalize=True).round(3)
# Out:
# 0    1255987
# 1       2889
# dtype: int64
# 0    0.998
# 1    0.002
# dtype: float64

# %% [markdown]
# # Populism by Politician

# %% [markdown]
# ## define funcs

# %%
def show_output(df, var):
    most_populist_pols = []
    for _, group in df.groupby("electoral_term"):
        out = group.sort_values(var, ascending=False)
        out["rank"] = list(range(1, len(out) + 1))
        most_populist_pols.append(out.head(5))
    return pd.concat(most_populist_pols)

# %%
def format_latex(tex):
    lines = tex.splitlines()
    new = []
    for i, line in enumerate(lines):
        # print(i, line)
        if i == 2:
            line = r"\headrow Term & Rank & First Name & Last Name & Party \\"
        if i == 3:
            continue
        if i == 5:
            line = line.replace(r"\multirow[c]{5}{*}{18}", r"\textbf{18}")
        if i == 10:
            line = line.replace(r"\multirow[c]{5}{*}{19}", r"\textbf{19}")
        if i == 10:
            new.append(r"& & & & \\\midrule")
        if 4 < i < 14:
            line = line + r"\midrule"
        new.append(line)

    tex = "\n".join(new)
    print(tex)

# %% [markdown]
# ## Populism by electoral_term and politician

# %%
df_pol = (
    df_raw.drop(["speech_id", "sentence_no", "date"], axis=1)
    .groupby(["pol_id", "first_name", "last_name", "abbreviation", "electoral_term"])
    .mean()
    .reset_index()
)

df_pol = df_pol.loc[df_pol.pol_id != -1, :]
df_pol["pop"] = df_pol.antielite * df_pol.pplcentr
df_pol["pop_left"] = df_pol["pop"] * df_pol.left
df_pol["pop_right"] = df_pol["pop"] * df_pol.right

# %% [markdown]
# ### general populism
#
# -> use this for table in paper

# %%
show_output(df_pol, "pop")
# Out:
#         pol_id first_name    last_name abbreviation  electoral_term  \
# 646   11004183      Sahra  Wagenknecht   DIE LINKE.              18
# 340   11003786      Katja      Kipping   DIE LINKE.              18
# 410   11003869     Sabine   Zimmermann   DIE LINKE.              18
# 261   11003625    Andreas      Scheuer      CDU/CSU              18
# 523   11004080      Jutta    Krellmann   DIE LINKE.              18
# 1278  11004892     Martin      Sichert          AfD              19
# 1309  11004930      Alice       Weidel          AfD              19
# 1250  11004859     Martin    Reichardt          AfD              19
# 1254  11004865      Bernd    Riexinger   DIE LINKE.              19
# 1104  11004698  Gottfried        Curio          AfD              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 646    0.309859  0.048709  0.119718  0.023474  0.015093  0.001807   0.000354
# 340    0.118351  0.085106  0.064495  0.007314  0.010072  0.000650   0.000074
# 410    0.121333  0.073886  0.055053  0.002898  0.008965  0.000494   0.000026
# 261    0.114094  0.073826  0.000000  0.033557  0.008423  0.000000   0.000283
# 523    0.124219  0.059681  0.042332  0.000000  0.007414  0.000314   0.000000
# 1278   0.315410  0.130492  0.050492  0.112131  0.041158  0.002078   0.004615
# 1309   0.389740  0.073507  0.035988  0.079632  0.028649  0.001031   0.002281
# 1250   0.267475  0.093438  0.027104  0.086305  0.024992  0.000677   0.002157
# 1254   0.189542  0.114379  0.124183  0.003268  0.021680  0.002692   0.000071
# 1104   0.283436  0.075617  0.006173  0.155350  0.021433  0.000132   0.003330
#
#       rank
# 646      1
# 340      2
# 410      3
# 261      4
# 523      5
# 1278     1
# 1309     2
# 1250     3
# 1254     4
# 1104     5

# %%
df = show_output(df_pol, "pop")

df = (
    df.rename({"abbreviation": "party"}, axis=1)
    .loc[:, ["electoral_term", "rank", "first_name", "last_name", "party"]]
    .set_index(["electoral_term", "rank"])
)

tex = df.style.to_latex(hrules=True)

format_latex(tex)
# Out:
# \begin{tabular}{lllll}
# \toprule
# \headrow Term & Rank & First Name & Last Name & Party \\
# \midrule
# \textbf{18} & 1 & Sahra & Wagenknecht & DIE LINKE. \\\midrule
#  & 2 & Katja & Kipping & DIE LINKE. \\\midrule
#  & 3 & Sabine & Zimmermann & DIE LINKE. \\\midrule
#  & 4 & Andreas & Scheuer & CDU/CSU \\\midrule
#  & 5 & Jutta & Krellmann & DIE LINKE. \\\midrule
# & & & & \\\midrule
# \textbf{19} & 1 & Martin & Sichert & AfD \\\midrule
#  & 2 & Alice & Weidel & AfD \\\midrule
#  & 3 & Martin & Reichardt & AfD \\\midrule
#  & 4 & Bernd & Riexinger & DIE LINKE. \\\midrule
#  & 5 & Gottfried & Curio & AfD \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### left-wing populism

# %%
show_output(df_pol, "pop_left")
# Out:
#         pol_id    first_name    last_name abbreviation  electoral_term  \
# 646   11004183         Sahra  Wagenknecht   DIE LINKE.              18
# 340   11003786         Katja      Kipping   DIE LINKE.              18
# 10    11000365  Jörg Diether   Dehm-Desoi   DIE LINKE.              18
# 410   11003869        Sabine   Zimmermann   DIE LINKE.              18
# 588   11004129       Richard     Pitterle   DIE LINKE.              18
# 1254  11004865         Bernd    Riexinger   DIE LINKE.              19
# 1278  11004892        Martin      Sichert          AfD              19
# 647   11004183         Sahra  Wagenknecht   DIE LINKE.              19
# 1231  11004837        Zaklin       Nastic   DIE LINKE.              19
# 341   11003786         Katja      Kipping   DIE LINKE.              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 646    0.309859  0.048709  0.119718  0.023474  0.015093  0.001807   0.000354
# 340    0.118351  0.085106  0.064495  0.007314  0.010072  0.000650   0.000074
# 10     0.232682  0.026643  0.095915  0.021314  0.006199  0.000595   0.000132
# 410    0.121333  0.073886  0.055053  0.002898  0.008965  0.000494   0.000026
# 588    0.156664  0.025721  0.080281  0.000000  0.004030  0.000323   0.000000
# 1254   0.189542  0.114379  0.124183  0.003268  0.021680  0.002692   0.000071
# 1278   0.315410  0.130492  0.050492  0.112131  0.041158  0.002078   0.004615
# 647    0.303333  0.056667  0.103333  0.008333  0.017189  0.001776   0.000143
# 1231   0.257340  0.063903  0.107081  0.024180  0.016445  0.001761   0.000398
# 341    0.132850  0.130435  0.088164  0.003623  0.017328  0.001528   0.000063
#
#       rank
# 646      1
# 340      2
# 10       3
# 410      4
# 588      5
# 1254     1
# 1278     2
# 647      3
# 1231     4
# 341      5

# %% [markdown]
# ### right-wing populism

# %%
show_output(df_pol, "pop_right")
# Out:
#         pol_id    first_name    last_name abbreviation  electoral_term  \
# 646   11004183         Sahra  Wagenknecht   DIE LINKE.              18
# 261   11003625       Andreas      Scheuer      CDU/CSU              18
# 309   11003746         Sevim     Dağdelen   DIE LINKE.              18
# 10    11000365  Jörg Diether   Dehm-Desoi   DIE LINKE.              18
# 340   11003786         Katja      Kipping   DIE LINKE.              18
# 1278  11004892        Martin      Sichert          AfD              19
# 1104  11004698     Gottfried        Curio          AfD              19
# 1309  11004930         Alice       Weidel          AfD              19
# 1250  11004859        Martin    Reichardt          AfD              19
# 1153  11004749        Martin         Hess          AfD              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 646    0.309859  0.048709  0.119718  0.023474  0.015093  0.001807   0.000354
# 261    0.114094  0.073826  0.000000  0.033557  0.008423  0.000000   0.000283
# 309    0.243608  0.028359  0.022780  0.034868  0.006908  0.000157   0.000241
# 10     0.232682  0.026643  0.095915  0.021314  0.006199  0.000595   0.000132
# 340    0.118351  0.085106  0.064495  0.007314  0.010072  0.000650   0.000074
# 1278   0.315410  0.130492  0.050492  0.112131  0.041158  0.002078   0.004615
# 1104   0.283436  0.075617  0.006173  0.155350  0.021433  0.000132   0.003330
# 1309   0.389740  0.073507  0.035988  0.079632  0.028649  0.001031   0.002281
# 1250   0.267475  0.093438  0.027104  0.086305  0.024992  0.000677   0.002157
# 1153   0.293129  0.061404  0.005117  0.112573  0.017999  0.000092   0.002026
#
#       rank
# 646      1
# 261      2
# 309      3
# 10       4
# 340      5
# 1278     1
# 1104     2
# 1309     3
# 1250     4
# 1153     5

# %% [markdown]
# ## Populism by Policitian + speech + electoral_term

# %%
df_speeches = (
    df_raw.drop(["sentence_no", "date"], axis=1)
    .groupby(
        [
            "pol_id",
            "first_name",
            "last_name",
            "abbreviation",
            "electoral_term",
            "speech_id",
        ]
    )
    .mean()
    .reset_index()
)
df_speeches = df_speeches.loc[df_speeches.pol_id != -1, :]
df_speeches["pop"] = df_speeches.antielite * df_speeches.pplcentr
df_speeches["pop_left"] = df_speeches["pop"] * df_speeches.left
df_speeches["pop_right"] = df_speeches["pop"] * df_speeches.right

df_pol = (
    df_speeches.drop("speech_id", axis=1)
    .groupby(["pol_id", "first_name", "last_name", "abbreviation", "electoral_term"])
    .mean()
    .reset_index()
)

# %% [markdown]
# ### general populism

# %%
show_output(df_pol, "pop")
# Out:
#         pol_id    first_name      last_name abbreviation  electoral_term  \
# 641   11004183         Sahra    Wagenknecht   DIE LINKE.              18
# 256   11003625       Andreas        Scheuer      CDU/CSU              18
# 405   11003869        Sabine     Zimmermann   DIE LINKE.              18
# 16    11001023          Ulla         Jelpke   DIE LINKE.              18
# 5     11000365  Jörg Diether     Dehm-Desoi   DIE LINKE.              18
# 1273  11004892        Martin        Sichert          AfD              19
# 1304  11004930         Alice         Weidel          AfD              19
# 1135  11004736  Mariana Iris  Harder-Kühnel          AfD              19
# 1245  11004859        Martin      Reichardt          AfD              19
# 1249  11004865         Bernd      Riexinger   DIE LINKE.              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 641    0.274289  0.039201  0.103937  0.025621  0.012490  0.001786   0.000593
# 256    0.112495  0.076862  0.000000  0.034879  0.008239  0.000000   0.000436
# 405    0.104987  0.073413  0.054851  0.001975  0.007884  0.000604   0.000013
# 16     0.143658  0.042774  0.038165  0.013965  0.007573  0.000738   0.000087
# 5      0.203880  0.020538  0.074360  0.021962  0.007298  0.001571   0.000161
# 1273   0.270665  0.114663  0.044342  0.103656  0.034284  0.002769   0.005539
# 1304   0.379145  0.072685  0.032144  0.073528  0.030785  0.001175   0.002545
# 1135   0.198616  0.102246  0.029713  0.100301  0.026049  0.003297   0.004667
# 1245   0.259349  0.086581  0.023207  0.081402  0.023748  0.001040   0.003140
# 1249   0.176643  0.109654  0.115164  0.003367  0.023342  0.004271   0.000291
#
#       rank
# 641      1
# 256      2
# 405      3
# 16       4
# 5        5
# 1273     1
# 1304     2
# 1135     3
# 1245     4
# 1249     5

# %% [markdown]
# ### left-wing populism

# %%
show_output(df_pol, "pop_left")
# Out:
#         pol_id    first_name      last_name abbreviation  electoral_term  \
# 323   11003773          Inge  Höger-Neuling   DIE LINKE.              18
# 641   11004183         Sahra    Wagenknecht   DIE LINKE.              18
# 5     11000365  Jörg Diether     Dehm-Desoi   DIE LINKE.              18
# 395   11003858     Alexander         Ulrich   DIE LINKE.              18
# 207   11003556      Gabriele     Hiller-Ohm          SPD              18
# 380   11003837       Gerhard         Schick        Grüne              19
# 336   11003786         Katja        Kipping   DIE LINKE.              19
# 1249  11004865         Bernd      Riexinger   DIE LINKE.              19
# 1135  11004736  Mariana Iris  Harder-Kühnel          AfD              19
# 6     11000365  Jörg Diether     Dehm-Desoi   DIE LINKE.              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 323    0.091668  0.013452  0.025414  0.003997  0.005170  0.002857   0.000029
# 641    0.274289  0.039201  0.103937  0.025621  0.012490  0.001786   0.000593
# 5      0.203880  0.020538  0.074360  0.021962  0.007298  0.001571   0.000161
# 395    0.212245  0.036868  0.044595  0.014548  0.007054  0.001110   0.000144
# 207    0.038301  0.041432  0.026086  0.000000  0.004176  0.000833   0.000000
# 380    0.163133  0.042694  0.106275  0.000000  0.013360  0.004554   0.000000
# 336    0.114209  0.122394  0.079609  0.002787  0.020963  0.004305   0.000177
# 1249   0.176643  0.109654  0.115164  0.003367  0.023342  0.004271   0.000291
# 1135   0.198616  0.102246  0.029713  0.100301  0.026049  0.003297   0.004667
# 6      0.169962  0.042400  0.048584  0.014086  0.012899  0.003209   0.000285
#
#       rank
# 323      1
# 641      2
# 5        3
# 395      4
# 207      5
# 380      1
# 336      2
# 1249     3
# 1135     4
# 6        5

# %% [markdown]
# ### right-wing populism

# %%
show_output(df_pol, "pop_right")
# Out:
#         pol_id    first_name      last_name abbreviation  electoral_term  \
# 213   11003572       Michael     Kretschmer      CDU/CSU              18
# 641   11004183         Sahra    Wagenknecht   DIE LINKE.              18
# 838   11004346        Yvonne         Magwas      CDU/CSU              18
# 256   11003625       Andreas        Scheuer      CDU/CSU              18
# 304   11003746         Sevim       Dağdelen   DIE LINKE.              18
# 1107  11004707        Thomas        Ehrhorn          AfD              19
# 1099  11004698     Gottfried          Curio          AfD              19
# 1273  11004892        Martin        Sichert          AfD              19
# 1135  11004736  Mariana Iris  Harder-Kühnel          AfD              19
# 1245  11004859        Martin      Reichardt          AfD              19
#
#       antielite  pplcentr      left     right       pop  pop_left  pop_right  \
# 213    0.043029  0.044400  0.004167  0.014113  0.007278  0.000058   0.001563
# 641    0.274289  0.039201  0.103937  0.025621  0.012490  0.001786   0.000593
# 838    0.059188  0.032314  0.003559  0.021350  0.004102  0.000001   0.000453
# 256    0.112495  0.076862  0.000000  0.034879  0.008239  0.000000   0.000436
# 304    0.162156  0.022724  0.016529  0.024319  0.004294  0.000433   0.000223
# 1107   0.246710  0.050332  0.012318  0.130780  0.020296  0.000206   0.009280
# 1099   0.269928  0.061637  0.003636  0.151902  0.022402  0.000102   0.006492
# 1273   0.270665  0.114663  0.044342  0.103656  0.034284  0.002769   0.005539
# 1135   0.198616  0.102246  0.029713  0.100301  0.026049  0.003297   0.004667
# 1245   0.259349  0.086581  0.023207  0.081402  0.023748  0.001040   0.003140
#
#       rank
# 213      1
# 641      2
# 838      3
# 256      4
# 304      5
# 1107     1
# 1099     2
# 1273     3
# 1135     4
# 1245     5
