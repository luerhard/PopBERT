# %%
# %load_ext autoreload
# %autoreload 2

# %%
import itertools as it

import pandas as pd
from nltk.metrics.agreement import AnnotationTask
from nltk.metrics.distance import jaccard_distance
from nltk.metrics.distance import masi_distance

import src.db.load
from src.coding.labels import LABELS
from src.coding.metrics import label_agreement
from src.coding.metrics import label_confusion
from src.db.connect import make_engine

# %%
# setup
engine = make_engine("DB")

pd.set_option("display.max_colwidth", 512)
pd.set_option("display.max_rows", None)

# %%
df = src.db.load.label_data(engine)

df_labels = df.explode("labels")
df_labels = df_labels[~df_labels.labels.str.startswith("no_")]

# %%
class AnnoTask(AnnotationTask):
    def load_data(self, array):
        self.C = set()
        self.K = set()
        self.I = set()
        self.data = []
        self.load_array(array)


task = AnnoTask(distance=jaccard_distance)

# %% [markdown]
# # Overall Evaluation
#
# ## Krippendorff's alpha
#
# ### all
#
# - all cases, including None
# - all cases, including those only labeled by a single coder

# %%
task.load_data(zip(df.username, df.sample_id, df.labels))
task.alpha()
# Out:
# 0.3722236712284903

# %%
task_df = df_labels.groupby(["sample_id", "username"]).agg(frozenset).reset_index()
task.load_data(zip(task_df.username, task_df.sample_id, task_df.labels))
task.alpha()
# Out:
# 0.698720596365064

# %% [markdown]
# # Krippendorff's alpha by label

# %% [markdown]
# ## at least 1 coder
#
# - documents are included if at least 1 coder has set the specific label on a document

# %%
labels = [l for l in df_labels.labels.unique()]

rows = []
for lab in labels:
    sub = (
        df_labels.groupby(["sample_id", "username"])["labels"]
        .agg(frozenset)
        .reset_index()
        .groupby("sample_id")
        .filter(lambda x: x.username.nunique() > 1)
        .groupby("sample_id")
        .filter(lambda x: x.labels.apply(lambda x: lab in x).any())
    )

    if sub.empty:
        row = (lab, -1, 0)
    else:
        task.load_data(zip(sub.username, sub.sample_id, sub.labels))
        alpha = round(task.alpha(), 3)
        row = (lab, alpha, sub.sample_id.nunique())

    rows.append(row)

# %%
alpha = pd.DataFrame(rows, columns=["label", "alpha", "n_docs"]).sort_values(
    "alpha", ascending=False
)
alpha.style.background_gradient()
# Out:
# <style type="text/css">
# #T_49d03_row0_col1, #T_49d03_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_49d03_row1_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_49d03_row1_col2 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_49d03_row2_col1 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_49d03_row2_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_49d03_row3_col1 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_49d03_row3_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_49d03_row4_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_49d03_row4_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_49d03_row5_col1, #T_49d03_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_49d03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49d03_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_49d03_level0_col1" class="col_heading level0 col1" >alpha</th>
#       <th id="T_49d03_level0_col2" class="col_heading level0 col2" >n_docs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49d03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49d03_row0_col0" class="data row0 col0" >antielite</td>
#       <td id="T_49d03_row0_col1" class="data row0 col1" >0.474000</td>
#       <td id="T_49d03_row0_col2" class="data row0 col2" >1433</td>
#     </tr>
#     <tr>
#       <th id="T_49d03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49d03_row1_col0" class="data row1 col0" >pplcentr</td>
#       <td id="T_49d03_row1_col1" class="data row1 col1" >0.452000</td>
#       <td id="T_49d03_row1_col2" class="data row1 col2" >695</td>
#     </tr>
#     <tr>
#       <th id="T_49d03_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_49d03_row2_col0" class="data row2 col0" >left</td>
#       <td id="T_49d03_row2_col1" class="data row2 col1" >0.394000</td>
#       <td id="T_49d03_row2_col2" class="data row2 col2" >504</td>
#     </tr>
#     <tr>
#       <th id="T_49d03_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_49d03_row3_col0" class="data row3 col0" >pplmore</td>
#       <td id="T_49d03_row3_col1" class="data row3 col1" >0.354000</td>
#       <td id="T_49d03_row3_col2" class="data row3 col2" >97</td>
#     </tr>
#     <tr>
#       <th id="T_49d03_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49d03_row4_col0" class="data row4 col0" >right</td>
#       <td id="T_49d03_row4_col1" class="data row4 col1" >0.309000</td>
#       <td id="T_49d03_row4_col2" class="data row4 col2" >311</td>
#     </tr>
#     <tr>
#       <th id="T_49d03_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_49d03_row5_col0" class="data row5 col0" >eliteless</td>
#       <td id="T_49d03_row5_col1" class="data row5 col1" >0.145000</td>
#       <td id="T_49d03_row5_col2" class="data row5 col2" >55</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## at least 2 coders
#
# - documents are included if at least 2 coder have set the specific label on a document

# %%
labels = [l for l in df_labels.labels.unique()]

rows = []

for lab in labels:
    sub = (
        df_labels.groupby(["sample_id", "username"])["labels"]
        .agg(frozenset)
        .reset_index()
        .groupby("sample_id")
        .filter(lambda x: x.username.nunique() > 1)
        .groupby("sample_id")
        .filter(lambda x: sum(x.labels.apply(lambda x: lab in x)) > 1)
    )

    if sub.empty:
        row = (lab, -1, 0)
    else:
        task.load_data(zip(sub.username, sub.sample_id, sub.labels))
        alpha = round(task.alpha(), 3)
        row = (lab, alpha, sub.sample_id.nunique())

    rows.append(row)

# %%
alpha_vals = pd.DataFrame(rows, columns=["label", "alpha", "n_docs"]).sort_values(
    "alpha", ascending=False
)
alpha_vals.style.background_gradient()
# Out:
# <style type="text/css">
# #T_9fae0_row0_col1, #T_9fae0_row1_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9fae0_row0_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_9fae0_row1_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_9fae0_row2_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_9fae0_row2_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_9fae0_row3_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_9fae0_row3_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_9fae0_row4_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_9fae0_row4_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9fae0_row5_col1, #T_9fae0_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_9fae0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fae0_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_9fae0_level0_col1" class="col_heading level0 col1" >alpha</th>
#       <th id="T_9fae0_level0_col2" class="col_heading level0 col2" >n_docs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fae0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9fae0_row0_col0" class="data row0 col0" >pplcentr</td>
#       <td id="T_9fae0_row0_col1" class="data row0 col1" >0.513000</td>
#       <td id="T_9fae0_row0_col2" class="data row0 col2" >513</td>
#     </tr>
#     <tr>
#       <th id="T_9fae0_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_9fae0_row1_col0" class="data row1 col0" >antielite</td>
#       <td id="T_9fae0_row1_col1" class="data row1 col1" >0.510000</td>
#       <td id="T_9fae0_row1_col2" class="data row1 col2" >1314</td>
#     </tr>
#     <tr>
#       <th id="T_9fae0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9fae0_row2_col0" class="data row2 col0" >left</td>
#       <td id="T_9fae0_row2_col1" class="data row2 col1" >0.478000</td>
#       <td id="T_9fae0_row2_col2" class="data row2 col2" >313</td>
#     </tr>
#     <tr>
#       <th id="T_9fae0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9fae0_row3_col0" class="data row3 col0" >right</td>
#       <td id="T_9fae0_row3_col1" class="data row3 col1" >0.320000</td>
#       <td id="T_9fae0_row3_col2" class="data row3 col2" >198</td>
#     </tr>
#     <tr>
#       <th id="T_9fae0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9fae0_row4_col0" class="data row4 col0" >pplmore</td>
#       <td id="T_9fae0_row4_col1" class="data row4 col1" >0.248000</td>
#       <td id="T_9fae0_row4_col2" class="data row4 col2" >67</td>
#     </tr>
#     <tr>
#       <th id="T_9fae0_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_9fae0_row5_col0" class="data row5 col0" >eliteless</td>
#       <td id="T_9fae0_row5_col1" class="data row5 col1" >0.125000</td>
#       <td id="T_9fae0_row5_col2" class="data row5 col2" >12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Custom Agreement Metric

# %%
labels = [l for l in df_labels.labels.unique()]

rows = []

for lab in labels:
    agreements = (
        df_labels.groupby(["sample_id", "username"])["labels"]
        .agg(frozenset)
        .reset_index()
        .groupby("sample_id")
        .filter(lambda x: x.username.nunique() > 1)
        .groupby("sample_id")
        .apply(lambda x: label_agreement(x.labels, lab))
    )

    mean_agreement = agreements.mean()
    n_docs = len(agreements[~agreements.isnull()])

    rows.append((lab, agreements.mean(), n_docs))

# %%
agreement = pd.DataFrame(rows, columns=["label", "agreement", "n_docs"]).sort_values(
    "agreement", ascending=False
)

metrics = pd.merge(alpha_vals, agreement.drop("n_docs", axis=1), on="label").sort_values(
    "agreement", ascending=False
)

metrics.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_06544_row0_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_06544_row0_col2, #T_06544_row0_col3, #T_06544_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_06544_row1_col2 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_06544_row1_col3 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_06544_row2_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_06544_row2_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_06544_row2_col3 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_06544_row3_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_06544_row3_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_06544_row3_col3 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_06544_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_06544_row4_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_06544_row4_col3 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_06544_row5_col1, #T_06544_row5_col2, #T_06544_row5_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_06544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06544_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_06544_level0_col1" class="col_heading level0 col1" >alpha</th>
#       <th id="T_06544_level0_col2" class="col_heading level0 col2" >n_docs</th>
#       <th id="T_06544_level0_col3" class="col_heading level0 col3" >agreement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06544_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_06544_row0_col0" class="data row0 col0" >antielite</td>
#       <td id="T_06544_row0_col1" class="data row0 col1" >0.510000</td>
#       <td id="T_06544_row0_col2" class="data row0 col2" >1314</td>
#       <td id="T_06544_row0_col3" class="data row0 col3" >0.886078</td>
#     </tr>
#     <tr>
#       <th id="T_06544_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_06544_row1_col0" class="data row1 col0" >pplcentr</td>
#       <td id="T_06544_row1_col1" class="data row1 col1" >0.513000</td>
#       <td id="T_06544_row1_col2" class="data row1 col2" >513</td>
#       <td id="T_06544_row1_col3" class="data row1 col3" >0.667770</td>
#     </tr>
#     <tr>
#       <th id="T_06544_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_06544_row2_col0" class="data row2 col0" >pplmore</td>
#       <td id="T_06544_row2_col1" class="data row2 col1" >0.248000</td>
#       <td id="T_06544_row2_col2" class="data row2 col2" >67</td>
#       <td id="T_06544_row2_col3" class="data row2 col3" >0.652062</td>
#     </tr>
#     <tr>
#       <th id="T_06544_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_06544_row3_col0" class="data row3 col0" >left</td>
#       <td id="T_06544_row3_col1" class="data row3 col1" >0.478000</td>
#       <td id="T_06544_row3_col2" class="data row3 col2" >313</td>
#       <td id="T_06544_row3_col3" class="data row3 col3" >0.511475</td>
#     </tr>
#     <tr>
#       <th id="T_06544_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_06544_row4_col0" class="data row4 col0" >right</td>
#       <td id="T_06544_row4_col1" class="data row4 col1" >0.320000</td>
#       <td id="T_06544_row4_col2" class="data row4 col2" >198</td>
#       <td id="T_06544_row4_col3" class="data row4 col3" >0.499357</td>
#     </tr>
#     <tr>
#       <th id="T_06544_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06544_row5_col0" class="data row5 col0" >eliteless</td>
#       <td id="T_06544_row5_col1" class="data row5 col1" >0.125000</td>
#       <td id="T_06544_row5_col2" class="data row5 col2" >12</td>
#       <td id="T_06544_row5_col3" class="data row5 col3" >0.137879</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Coherence of metrics
#
# - alpha seems to be more dependent on number of docs

# %%
metrics.corr("pearson", numeric_only=True)
# Out:
#               alpha    n_docs  agreement
# alpha      1.000000  0.725956   0.754392
# n_docs     0.725956  1.000000   0.766712
# agreement  0.754392  0.766712   1.000000

# %%
metrics.corr("spearman", numeric_only=True)
# Out:
#               alpha    n_docs  agreement
# alpha      1.000000  0.942857   0.771429
# n_docs     0.942857  1.000000   0.828571
# agreement  0.771429  0.828571   1.000000

# %% [markdown]
# # Labels Pairwise
#
# - General setting:
#   - docs with less than 2 coders are ignored
#   - docs must be coded with both labels of the pair at least once, otherwise they are ignored

# %%
# setup


def pivot(df, values, precision):
    """reformats and displays a pivot table

    Args:
        df: DataFrame to be pivoted
        values (Any): value to be pivoted
        precision (int): precision for values in table
    """
    piv = pd.pivot(df, index="label1", columns="label2", values=values).fillna(value=0)
    piv = piv.reindex(sorted(piv.columns), axis=1).reindex(sorted(piv.index), axis=0)

    return piv.style.background_gradient(axis=None).format(precision=precision)

# %% [markdown]
# ### Create Data

# %%
labels = [l for l in df_labels.labels.unique()]

rows = []
for labs in it.combinations(labels, r=2):
    confusion = (
        df_labels.groupby("sample_id")
        .filter(
            lambda x: x.labels.str.contains(labs[0]).any() and x.labels.str.contains(labs[1]).any()
        )
        .groupby(["sample_id", "username"])["labels"]
        .agg(frozenset)
        .reset_index()
        .groupby("sample_id")
        .filter(lambda x: x.username.nunique() > 1)
        .groupby("sample_id", group_keys=False)
        .apply(lambda x: label_confusion(x.labels, *labs))
    )

    if confusion.empty:
        rows.append((*sorted(labs, reverse=True), 0, 0))
        rows.append((*sorted(labs, reverse=False), 0, 0))
        continue

    mean_confusion = confusion.mean()
    n_docs = len(confusion[~confusion.isnull()])

    rows.append((*sorted(labs, reverse=True), mean_confusion, n_docs))
    rows.append((*sorted(labs, reverse=False), mean_confusion, n_docs))

confusion = pd.DataFrame(rows, columns=["label1", "label2", "confusion", "n_docs"])

# %%
print(confusion.corr("pearson", numeric_only=True))

print(confusion.corr("spearman", numeric_only=True))
# Out:
#            confusion   n_docs
# confusion    1.00000 -0.37038
# n_docs      -0.37038  1.00000
#            confusion    n_docs
# confusion   1.000000 -0.169795
# n_docs     -0.169795  1.000000

# %% [markdown]
# ## Pairwise Counts
#
# - Question: How often are labels set pairwise on a single document?
# - Can be of the same or different coders

# %%
pivot(confusion, "n_docs", 0)
# Out:
# <style type="text/css">
# #T_64246_row0_col0, #T_64246_row1_col1, #T_64246_row2_col2, #T_64246_row3_col3, #T_64246_row4_col4, #T_64246_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_64246_row0_col1, #T_64246_row1_col0 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_64246_row0_col2, #T_64246_row2_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_64246_row0_col3, #T_64246_row3_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_64246_row0_col4, #T_64246_row1_col3, #T_64246_row3_col1, #T_64246_row4_col0 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_64246_row0_col5, #T_64246_row5_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_64246_row1_col2, #T_64246_row2_col1, #T_64246_row2_col4, #T_64246_row4_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_64246_row1_col4, #T_64246_row4_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_64246_row1_col5, #T_64246_row5_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_64246_row2_col3, #T_64246_row3_col2 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_64246_row2_col5, #T_64246_row5_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_64246_row3_col4, #T_64246_row4_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_64246_row3_col5, #T_64246_row5_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_64246_row4_col5, #T_64246_row5_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_64246">
#   <thead>
#     <tr>
#       <th class="index_name level0" >label2</th>
#       <th id="T_64246_level0_col0" class="col_heading level0 col0" >antielite</th>
#       <th id="T_64246_level0_col1" class="col_heading level0 col1" >eliteless</th>
#       <th id="T_64246_level0_col2" class="col_heading level0 col2" >left</th>
#       <th id="T_64246_level0_col3" class="col_heading level0 col3" >pplcentr</th>
#       <th id="T_64246_level0_col4" class="col_heading level0 col4" >pplmore</th>
#       <th id="T_64246_level0_col5" class="col_heading level0 col5" >right</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >label1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64246_level0_row0" class="row_heading level0 row0" >antielite</th>
#       <td id="T_64246_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_64246_row0_col1" class="data row0 col1" >47</td>
#       <td id="T_64246_row0_col2" class="data row0 col2" >369</td>
#       <td id="T_64246_row0_col3" class="data row0 col3" >266</td>
#       <td id="T_64246_row0_col4" class="data row0 col4" >12</td>
#       <td id="T_64246_row0_col5" class="data row0 col5" >285</td>
#     </tr>
#     <tr>
#       <th id="T_64246_level0_row1" class="row_heading level0 row1" >eliteless</th>
#       <td id="T_64246_row1_col0" class="data row1 col0" >47</td>
#       <td id="T_64246_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_64246_row1_col2" class="data row1 col2" >18</td>
#       <td id="T_64246_row1_col3" class="data row1 col3" >12</td>
#       <td id="T_64246_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_64246_row1_col5" class="data row1 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_64246_level0_row2" class="row_heading level0 row2" >left</th>
#       <td id="T_64246_row2_col0" class="data row2 col0" >369</td>
#       <td id="T_64246_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_64246_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_64246_row2_col3" class="data row2 col3" >245</td>
#       <td id="T_64246_row2_col4" class="data row2 col4" >16</td>
#       <td id="T_64246_row2_col5" class="data row2 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_64246_level0_row3" class="row_heading level0 row3" >pplcentr</th>
#       <td id="T_64246_row3_col0" class="data row3 col0" >266</td>
#       <td id="T_64246_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_64246_row3_col2" class="data row3 col2" >245</td>
#       <td id="T_64246_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_64246_row3_col4" class="data row3 col4" >31</td>
#       <td id="T_64246_row3_col5" class="data row3 col5" >80</td>
#     </tr>
#     <tr>
#       <th id="T_64246_level0_row4" class="row_heading level0 row4" >pplmore</th>
#       <td id="T_64246_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_64246_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_64246_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_64246_row4_col3" class="data row4 col3" >31</td>
#       <td id="T_64246_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_64246_row4_col5" class="data row4 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_64246_level0_row5" class="row_heading level0 row5" >right</th>
#       <td id="T_64246_row5_col0" class="data row5 col0" >285</td>
#       <td id="T_64246_row5_col1" class="data row5 col1" >11</td>
#       <td id="T_64246_row5_col2" class="data row5 col2" >24</td>
#       <td id="T_64246_row5_col3" class="data row5 col3" >80</td>
#       <td id="T_64246_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_64246_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Pairwise Confusion
#
# - Question: How much better had the agreement been if the worse label had been coded as the better one?
# - Higher values show higher confusion

# %%
pivot(confusion, "confusion", 3)
# Out:
# <style type="text/css">
# #T_a2eb9_row0_col0, #T_a2eb9_row1_col1, #T_a2eb9_row2_col2, #T_a2eb9_row2_col5, #T_a2eb9_row3_col3, #T_a2eb9_row4_col4, #T_a2eb9_row4_col5, #T_a2eb9_row5_col2, #T_a2eb9_row5_col4, #T_a2eb9_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a2eb9_row0_col1, #T_a2eb9_row1_col0, #T_a2eb9_row2_col4, #T_a2eb9_row4_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_a2eb9_row0_col2, #T_a2eb9_row2_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a2eb9_row0_col3, #T_a2eb9_row3_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_a2eb9_row0_col4, #T_a2eb9_row3_col5, #T_a2eb9_row4_col0, #T_a2eb9_row5_col3 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_a2eb9_row0_col5, #T_a2eb9_row5_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a2eb9_row1_col2, #T_a2eb9_row2_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a2eb9_row1_col3, #T_a2eb9_row1_col5, #T_a2eb9_row3_col1, #T_a2eb9_row5_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a2eb9_row1_col4, #T_a2eb9_row4_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a2eb9_row2_col3, #T_a2eb9_row3_col2 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_a2eb9_row3_col4, #T_a2eb9_row4_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2eb9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >label2</th>
#       <th id="T_a2eb9_level0_col0" class="col_heading level0 col0" >antielite</th>
#       <th id="T_a2eb9_level0_col1" class="col_heading level0 col1" >eliteless</th>
#       <th id="T_a2eb9_level0_col2" class="col_heading level0 col2" >left</th>
#       <th id="T_a2eb9_level0_col3" class="col_heading level0 col3" >pplcentr</th>
#       <th id="T_a2eb9_level0_col4" class="col_heading level0 col4" >pplmore</th>
#       <th id="T_a2eb9_level0_col5" class="col_heading level0 col5" >right</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >label1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2eb9_level0_row0" class="row_heading level0 row0" >antielite</th>
#       <td id="T_a2eb9_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_a2eb9_row0_col1" class="data row0 col1" >0.269</td>
#       <td id="T_a2eb9_row0_col2" class="data row0 col2" >0.031</td>
#       <td id="T_a2eb9_row0_col3" class="data row0 col3" >0.395</td>
#       <td id="T_a2eb9_row0_col4" class="data row0 col4" >0.333</td>
#       <td id="T_a2eb9_row0_col5" class="data row0 col5" >0.054</td>
#     </tr>
#     <tr>
#       <th id="T_a2eb9_level0_row1" class="row_heading level0 row1" >eliteless</th>
#       <td id="T_a2eb9_row1_col0" class="data row1 col0" >0.269</td>
#       <td id="T_a2eb9_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_a2eb9_row1_col2" class="data row1 col2" >0.241</td>
#       <td id="T_a2eb9_row1_col3" class="data row1 col3" >0.250</td>
#       <td id="T_a2eb9_row1_col4" class="data row1 col4" >0.625</td>
#       <td id="T_a2eb9_row1_col5" class="data row1 col5" >0.250</td>
#     </tr>
#     <tr>
#       <th id="T_a2eb9_level0_row2" class="row_heading level0 row2" >left</th>
#       <td id="T_a2eb9_row2_col0" class="data row2 col0" >0.031</td>
#       <td id="T_a2eb9_row2_col1" class="data row2 col1" >0.241</td>
#       <td id="T_a2eb9_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_a2eb9_row2_col3" class="data row2 col3" >0.127</td>
#       <td id="T_a2eb9_row2_col4" class="data row2 col4" >0.267</td>
#       <td id="T_a2eb9_row2_col5" class="data row2 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a2eb9_level0_row3" class="row_heading level0 row3" >pplcentr</th>
#       <td id="T_a2eb9_row3_col0" class="data row3 col0" >0.395</td>
#       <td id="T_a2eb9_row3_col1" class="data row3 col1" >0.250</td>
#       <td id="T_a2eb9_row3_col2" class="data row3 col2" >0.127</td>
#       <td id="T_a2eb9_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_a2eb9_row3_col4" class="data row3 col4" >0.583</td>
#       <td id="T_a2eb9_row3_col5" class="data row3 col5" >0.333</td>
#     </tr>
#     <tr>
#       <th id="T_a2eb9_level0_row4" class="row_heading level0 row4" >pplmore</th>
#       <td id="T_a2eb9_row4_col0" class="data row4 col0" >0.333</td>
#       <td id="T_a2eb9_row4_col1" class="data row4 col1" >0.625</td>
#       <td id="T_a2eb9_row4_col2" class="data row4 col2" >0.267</td>
#       <td id="T_a2eb9_row4_col3" class="data row4 col3" >0.583</td>
#       <td id="T_a2eb9_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_a2eb9_row4_col5" class="data row4 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a2eb9_level0_row5" class="row_heading level0 row5" >right</th>
#       <td id="T_a2eb9_row5_col0" class="data row5 col0" >0.054</td>
#       <td id="T_a2eb9_row5_col1" class="data row5 col1" >0.250</td>
#       <td id="T_a2eb9_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_a2eb9_row5_col3" class="data row5 col3" >0.333</td>
#       <td id="T_a2eb9_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_a2eb9_row5_col5" class="data row5 col5" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Pairwise 2
#
# - Change: less data restrictions
# - Only 1 of the 2 labels has to be present for a doc to count

# %% [markdown]
# ### Create Data

# %%
labels = [l for l in df_labels.labels.unique()]

rows = []

for labs in it.combinations(labels, r=2):
    confusion = (
        df_labels.groupby("sample_id")
        .filter(lambda x: x.labels.isin(labs).any())
        .groupby(["sample_id", "username"])["labels"]
        .agg(frozenset)
        .reset_index()
        .groupby("sample_id")
        .filter(lambda x: x.username.nunique() > 1)
        .groupby("sample_id", group_keys=False)
        .apply(lambda x: label_confusion(x.labels, *labs))
    )

    if confusion.empty:
        rows.append((*sorted(labs, reverse=True), 0, 0))
        rows.append((*sorted(labs, reverse=False), 0, 0))
        continue

    mean_confusion = confusion.mean()
    n_docs = len(confusion[~confusion.isnull()])

    rows.append((*sorted(labs, reverse=True), mean_confusion, n_docs))
    rows.append((*sorted(labs, reverse=False), mean_confusion, n_docs))

confusion = pd.DataFrame(rows, columns=["label1", "label2", "confusion", "n_docs"])

# %%
print(confusion.corr("pearson", numeric_only=True))

print(confusion.corr("spearman", numeric_only=True))
# Out:
#            confusion    n_docs
# confusion   1.000000 -0.031535
# n_docs     -0.031535  1.000000
#            confusion   n_docs
# confusion    1.00000  0.01966
# n_docs       0.01966  1.00000

# %% [markdown]
# ### Pairwise Counts 2

# %%
pivot(confusion, "n_docs", 0)
# Out:
# <style type="text/css">
# #T_8a828_row0_col0, #T_8a828_row1_col1, #T_8a828_row2_col2, #T_8a828_row3_col3, #T_8a828_row4_col4, #T_8a828_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_8a828_row0_col1, #T_8a828_row1_col0 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_8a828_row0_col2, #T_8a828_row2_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_8a828_row0_col3, #T_8a828_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8a828_row0_col4, #T_8a828_row4_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_8a828_row0_col5, #T_8a828_row5_col0 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_8a828_row1_col2, #T_8a828_row2_col1 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_8a828_row1_col3, #T_8a828_row3_col1 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_8a828_row1_col4, #T_8a828_row4_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_8a828_row1_col5, #T_8a828_row5_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_8a828_row2_col3, #T_8a828_row3_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_8a828_row2_col4, #T_8a828_row4_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_8a828_row2_col5, #T_8a828_row5_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_8a828_row3_col4, #T_8a828_row4_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_8a828_row3_col5, #T_8a828_row5_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_8a828_row4_col5, #T_8a828_row5_col4 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# </style>
# <table id="T_8a828">
#   <thead>
#     <tr>
#       <th class="index_name level0" >label2</th>
#       <th id="T_8a828_level0_col0" class="col_heading level0 col0" >antielite</th>
#       <th id="T_8a828_level0_col1" class="col_heading level0 col1" >eliteless</th>
#       <th id="T_8a828_level0_col2" class="col_heading level0 col2" >left</th>
#       <th id="T_8a828_level0_col3" class="col_heading level0 col3" >pplcentr</th>
#       <th id="T_8a828_level0_col4" class="col_heading level0 col4" >pplmore</th>
#       <th id="T_8a828_level0_col5" class="col_heading level0 col5" >right</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >label1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a828_level0_row0" class="row_heading level0 row0" >antielite</th>
#       <td id="T_8a828_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8a828_row0_col1" class="data row0 col1" >376</td>
#       <td id="T_8a828_row0_col2" class="data row0 col2" >380</td>
#       <td id="T_8a828_row0_col3" class="data row0 col3" >419</td>
#       <td id="T_8a828_row0_col4" class="data row0 col4" >404</td>
#       <td id="T_8a828_row0_col5" class="data row0 col5" >374</td>
#     </tr>
#     <tr>
#       <th id="T_8a828_level0_row1" class="row_heading level0 row1" >eliteless</th>
#       <td id="T_8a828_row1_col0" class="data row1 col0" >376</td>
#       <td id="T_8a828_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_8a828_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_8a828_row1_col3" class="data row1 col3" >98</td>
#       <td id="T_8a828_row1_col4" class="data row1 col4" >54</td>
#       <td id="T_8a828_row1_col5" class="data row1 col5" >46</td>
#     </tr>
#     <tr>
#       <th id="T_8a828_level0_row2" class="row_heading level0 row2" >left</th>
#       <td id="T_8a828_row2_col0" class="data row2 col0" >380</td>
#       <td id="T_8a828_row2_col1" class="data row2 col1" >100</td>
#       <td id="T_8a828_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_8a828_row2_col3" class="data row2 col3" >149</td>
#       <td id="T_8a828_row2_col4" class="data row2 col4" >120</td>
#       <td id="T_8a828_row2_col5" class="data row2 col5" >115</td>
#     </tr>
#     <tr>
#       <th id="T_8a828_level0_row3" class="row_heading level0 row3" >pplcentr</th>
#       <td id="T_8a828_row3_col0" class="data row3 col0" >419</td>
#       <td id="T_8a828_row3_col1" class="data row3 col1" >98</td>
#       <td id="T_8a828_row3_col2" class="data row3 col2" >149</td>
#       <td id="T_8a828_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_8a828_row3_col4" class="data row3 col4" >108</td>
#       <td id="T_8a828_row3_col5" class="data row3 col5" >105</td>
#     </tr>
#     <tr>
#       <th id="T_8a828_level0_row4" class="row_heading level0 row4" >pplmore</th>
#       <td id="T_8a828_row4_col0" class="data row4 col0" >404</td>
#       <td id="T_8a828_row4_col1" class="data row4 col1" >54</td>
#       <td id="T_8a828_row4_col2" class="data row4 col2" >120</td>
#       <td id="T_8a828_row4_col3" class="data row4 col3" >108</td>
#       <td id="T_8a828_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_8a828_row4_col5" class="data row4 col5" >64</td>
#     </tr>
#     <tr>
#       <th id="T_8a828_level0_row5" class="row_heading level0 row5" >right</th>
#       <td id="T_8a828_row5_col0" class="data row5 col0" >374</td>
#       <td id="T_8a828_row5_col1" class="data row5 col1" >46</td>
#       <td id="T_8a828_row5_col2" class="data row5 col2" >115</td>
#       <td id="T_8a828_row5_col3" class="data row5 col3" >105</td>
#       <td id="T_8a828_row5_col4" class="data row5 col4" >64</td>
#       <td id="T_8a828_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Pairwise Confusion 2
#
# - Question: How much better had the agreement been if the worse label had been coded as the better one?
# - Higher values show higher confusion

# %%
pivot(confusion, "confusion", 3)
# Out:
# <style type="text/css">
# #T_c3f5a_row0_col0, #T_c3f5a_row1_col1, #T_c3f5a_row2_col2, #T_c3f5a_row2_col5, #T_c3f5a_row3_col3, #T_c3f5a_row4_col4, #T_c3f5a_row4_col5, #T_c3f5a_row5_col2, #T_c3f5a_row5_col4, #T_c3f5a_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c3f5a_row0_col1, #T_c3f5a_row1_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_c3f5a_row0_col2, #T_c3f5a_row2_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_c3f5a_row0_col3, #T_c3f5a_row3_col0 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_c3f5a_row0_col4, #T_c3f5a_row4_col0 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_c3f5a_row0_col5, #T_c3f5a_row5_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c3f5a_row1_col2, #T_c3f5a_row2_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_c3f5a_row1_col3, #T_c3f5a_row3_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c3f5a_row1_col4, #T_c3f5a_row4_col1 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_c3f5a_row1_col5, #T_c3f5a_row5_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_c3f5a_row2_col3, #T_c3f5a_row3_col2 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_c3f5a_row2_col4, #T_c3f5a_row4_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_c3f5a_row3_col4, #T_c3f5a_row4_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c3f5a_row3_col5, #T_c3f5a_row5_col3 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# </style>
# <table id="T_c3f5a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >label2</th>
#       <th id="T_c3f5a_level0_col0" class="col_heading level0 col0" >antielite</th>
#       <th id="T_c3f5a_level0_col1" class="col_heading level0 col1" >eliteless</th>
#       <th id="T_c3f5a_level0_col2" class="col_heading level0 col2" >left</th>
#       <th id="T_c3f5a_level0_col3" class="col_heading level0 col3" >pplcentr</th>
#       <th id="T_c3f5a_level0_col4" class="col_heading level0 col4" >pplmore</th>
#       <th id="T_c3f5a_level0_col5" class="col_heading level0 col5" >right</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >label1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3f5a_level0_row0" class="row_heading level0 row0" >antielite</th>
#       <td id="T_c3f5a_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_c3f5a_row0_col1" class="data row0 col1" >0.013</td>
#       <td id="T_c3f5a_row0_col2" class="data row0 col2" >0.007</td>
#       <td id="T_c3f5a_row0_col3" class="data row0 col3" >0.033</td>
#       <td id="T_c3f5a_row0_col4" class="data row0 col4" >0.005</td>
#       <td id="T_c3f5a_row0_col5" class="data row0 col5" >0.004</td>
#     </tr>
#     <tr>
#       <th id="T_c3f5a_level0_row1" class="row_heading level0 row1" >eliteless</th>
#       <td id="T_c3f5a_row1_col0" class="data row1 col0" >0.013</td>
#       <td id="T_c3f5a_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_c3f5a_row1_col2" class="data row1 col2" >0.022</td>
#       <td id="T_c3f5a_row1_col3" class="data row1 col3" >0.005</td>
#       <td id="T_c3f5a_row1_col4" class="data row1 col4" >0.023</td>
#       <td id="T_c3f5a_row1_col5" class="data row1 col5" >0.011</td>
#     </tr>
#     <tr>
#       <th id="T_c3f5a_level0_row2" class="row_heading level0 row2" >left</th>
#       <td id="T_c3f5a_row2_col0" class="data row2 col0" >0.007</td>
#       <td id="T_c3f5a_row2_col1" class="data row2 col1" >0.022</td>
#       <td id="T_c3f5a_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_c3f5a_row2_col3" class="data row2 col3" >0.017</td>
#       <td id="T_c3f5a_row2_col4" class="data row2 col4" >0.011</td>
#       <td id="T_c3f5a_row2_col5" class="data row2 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_c3f5a_level0_row3" class="row_heading level0 row3" >pplcentr</th>
#       <td id="T_c3f5a_row3_col0" class="data row3 col0" >0.033</td>
#       <td id="T_c3f5a_row3_col1" class="data row3 col1" >0.005</td>
#       <td id="T_c3f5a_row3_col2" class="data row3 col2" >0.017</td>
#       <td id="T_c3f5a_row3_col3" class="data row3 col3" >0.000</td>
#       <td id="T_c3f5a_row3_col4" class="data row3 col4" >0.043</td>
#       <td id="T_c3f5a_row3_col5" class="data row3 col5" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_c3f5a_level0_row4" class="row_heading level0 row4" >pplmore</th>
#       <td id="T_c3f5a_row4_col0" class="data row4 col0" >0.005</td>
#       <td id="T_c3f5a_row4_col1" class="data row4 col1" >0.023</td>
#       <td id="T_c3f5a_row4_col2" class="data row4 col2" >0.011</td>
#       <td id="T_c3f5a_row4_col3" class="data row4 col3" >0.043</td>
#       <td id="T_c3f5a_row4_col4" class="data row4 col4" >0.000</td>
#       <td id="T_c3f5a_row4_col5" class="data row4 col5" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_c3f5a_level0_row5" class="row_heading level0 row5" >right</th>
#       <td id="T_c3f5a_row5_col0" class="data row5 col0" >0.004</td>
#       <td id="T_c3f5a_row5_col1" class="data row5 col1" >0.011</td>
#       <td id="T_c3f5a_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_c3f5a_row5_col3" class="data row5 col3" >0.010</td>
#       <td id="T_c3f5a_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_c3f5a_row5_col5" class="data row5 col5" >0.000</td>
#     </tr>
#   </tbody>
# </table>
